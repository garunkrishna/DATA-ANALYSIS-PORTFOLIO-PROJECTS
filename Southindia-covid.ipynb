# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ARUN KRISHNA\Documents\South india covid.csv")
df
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andhra Pradesh      2340676       0     2325943   14733             0
# 1       Karnataka      4088769      12     4048399   40358             0
# 2          Kerala      6907241      18     6835181   72042             0
# 3  Madhya Pradesh      1056351       0     1045565   10786             0
# 4      Tamil Nadu      3610655       5     3572569   38081             0
# 5       Telengana       844432       8      840313    4111             0
#
#    Discharge Ratio  Death Ratio  Population
# 0            99.37         0.63   128500364
# 1            99.01         0.99     1711947
# 2            98.96         1.04    91702478
# 3            98.98         1.02    14999397
# 4            98.95         1.05    35998752
# 5            99.51         0.49    69599762

# %%
print(plt.style.available)
plt.style.use('dark_background')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df=pd.read_csv(r"C:\Users\ARUN KRISHNA\Documents\South india covid.csv",index_col='State/UTs')
df
# Out:
#                 Total Cases  Active  Discharged  Deaths  Active Ratio  \
# State/UTs
# Andhra Pradesh      2340676       0     2325943   14733             0
# Karnataka           4088769      12     4048399   40358             0
# Kerala              6907241      18     6835181   72042             0
# Madhya Pradesh      1056351       0     1045565   10786             0
# Tamil Nadu          3610655       5     3572569   38081             0
# Telengana            844432       8      840313    4111             0
#
#                 Discharge Ratio  Death Ratio  Population
# State/UTs
# Andhra Pradesh            99.37         0.63   128500364
# Karnataka                 99.01         0.99     1711947
# Kerala                    98.96         1.04    91702478
# Madhya Pradesh            98.98         1.02    14999397
# Tamil Nadu                98.95         1.05    35998752
# Telengana                 99.51         0.49    69599762

# %%
df['Deaths'].plot.barh(title='covid summary',stacked=True,figsize=(10,5))
# Out:
# <Axes: title={'center': 'covid summary'}, ylabel='State/UTs'>

# %%
df.plot.area(subplots=True,figsize=(10,5))
# Out:
# array([<Axes: xlabel='State/UTs'>, <Axes: xlabel='State/UTs'>,
#        <Axes: xlabel='State/UTs'>, <Axes: xlabel='State/UTs'>,
#        <Axes: xlabel='State/UTs'>, <Axes: xlabel='State/UTs'>,
#        <Axes: xlabel='State/UTs'>, <Axes: xlabel='State/UTs'>],
#       dtype=object)

# %%
df.plot(kind='line',y='Deaths',subplots=True,figsize=(10,5))
plt.style.use('dark_background')

# %%
df.plot.pie(y='Deaths',figsize=(10,10))
# Out:
# <Axes: ylabel='Deaths'>

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='State/UTs'>

# %%
df.loc['Telengana']
# Out:
# Total Cases          844432.00
# Active                    8.00
# Discharged           840313.00
# Deaths                 4111.00
# Active Ratio              0.00
# Discharge Ratio          99.51
# Death Ratio               0.49
# Population         69599762.00
# Name: Telengana, dtype: float64

# %%
group_by_state=df.groupby(['Deaths'])

# %%
df.groupby('State/UTs').min()
# Out:
#                 Total Cases  Active  Discharged  Deaths  Active Ratio  \
# State/UTs
# Andhra Pradesh      2340676       0     2325943   14733             0
# Karnataka           4088769      12     4048399   40358             0
# Kerala              6907241      18     6835181   72042             0
# Madhya Pradesh      1056351       0     1045565   10786             0
# Tamil Nadu          3610655       5     3572569   38081             0
# Telengana            844432       8      840313    4111             0
#
#                 Discharge Ratio  Death Ratio  Population
# State/UTs
# Andhra Pradesh            99.37         0.63   128500364
# Karnataka                 99.01         0.99     1711947
# Kerala                    98.96         1.04    91702478
# Madhya Pradesh            98.98         1.02    14999397
# Tamil Nadu                98.95         1.05    35998752
# Telengana                 99.51         0.49    69599762

# %%
df.plot.area(figsize=(10,10))
# Out:
# <Axes: xlabel='State/UTs'>
